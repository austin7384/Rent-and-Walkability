# %%
import pandas as pd
import numpy as np
import geopandas as gpd
from shapely.geometry import Point

# %%
dfCrime = pd.read_csv('/Users/austincoffelt/Downloads/Crimes_-_2001_to_Present.csv')
print(dfCrime.shape)
dfCrime.head()
# Out:
# (8285876, 22)
#          ID Case Number                    Date                    Block  \
# 0  13311263    JG503434  07/29/2022 03:39:00 AM          023XX S TROY ST
# 1  13053066    JG103252  01/03/2023 04:44:00 PM  039XX W WASHINGTON BLVD
# 2  11227634    JB147599  08/26/2017 10:00:00 AM      001XX W RANDOLPH ST
# 3  13203321    JG415333  09/06/2023 05:00:00 PM         002XX N Wells st
# 4  13204489    JG416325  09/06/2023 11:00:00 AM           0000X E 8TH ST
#
#    IUCR                Primary Type                    Description  \
# 0  1582  OFFENSE INVOLVING CHILDREN              CHILD PORNOGRAPHY
# 1  2017                   NARCOTICS  MANUFACTURE / DELIVER - CRACK
# 2  0281         CRIM SEXUAL ASSAULT                 NON-AGGRAVATED
# 3  1320             CRIMINAL DAMAGE                     TO VEHICLE
# 4  0810                       THEFT                      OVER $500
#
#                      Location Description  Arrest  Domestic  ...  Ward  \
# 0                               RESIDENCE    True     False  ...  25.0
# 1                                SIDEWALK    True     False  ...  28.0
# 2                             HOTEL/MOTEL   False     False  ...  42.0
# 3  PARKING LOT / GARAGE (NON RESIDENTIAL)   False     False  ...  42.0
# 4  PARKING LOT / GARAGE (NON RESIDENTIAL)   False     False  ...   4.0
#
#    Community Area  FBI Code  X Coordinate Y Coordinate  Year  \
# 0            30.0        17           NaN          NaN  2022
# 1            26.0        18           NaN          NaN  2023
# 2            32.0        02           NaN          NaN  2017
# 3            32.0        14     1174694.0    1901831.0  2023
# 4            32.0        06     1176857.0    1896680.0  2023
#
#                Updated On   Latitude  Longitude                       Location
# 0  04/18/2024 03:40:59 PM        NaN        NaN                            NaN
# 1  01/20/2024 03:41:12 PM        NaN        NaN                            NaN
# 2  02/11/2018 03:57:41 PM        NaN        NaN                            NaN
# 3  11/04/2023 03:40:18 PM  41.886018 -87.633938  (41.886018055, -87.633937881)
# 4  11/04/2023 03:40:18 PM  41.871835 -87.626151   (41.871834768, -87.62615082)
#
# [5 rows x 22 columns]

# %%
dfCrime.dtypes
# Out:
# ID                        int64
# Case Number              object
# Date                     object
# Block                    object
# IUCR                     object
# Primary Type             object
# Description              object
# Location Description     object
# Arrest                     bool
# Domestic                   bool
# Beat                      int64
# District                float64
# Ward                    float64
# Community Area          float64
# FBI Code                 object
# X Coordinate            float64
# Y Coordinate            float64
# Year                      int64
# Updated On               object
# Latitude                float64
# Longitude               float64
# Location                 object
# dtype: object

# %%
dfCrime = dfCrime[dfCrime['Year'] == 2021]
dfCrime = dfCrime[(dfCrime['Latitude'].isna() == False) & (dfCrime['Longitude'].isna() == False)]
print(dfCrime.shape)
dfCrime.head()
# Out:
# (202873, 22)
#            ID Case Number                    Date                  Block  \
# 6    12419690    JE295655  07/07/2021 10:30:00 AM  132XX S GREENWOOD AVE
# 20   12342615    JE202211  04/17/2021 03:20:00 PM    081XX S PRAIRIE AVE
# 84      26262    JE366265  09/08/2021 04:45:00 PM    047XX W HARRISON ST
# 849  12298539    JE148775  02/22/2021 01:36:00 PM      015XX S DRAKE AVE
# 851  12346572    JE206964  04/22/2021 02:30:00 PM        016XX W 59TH ST
#
#      IUCR        Primary Type                     Description  \
# 6    1544         SEX OFFENSE  SEXUAL EXPLOITATION OF A CHILD
# 20   0325             ROBBERY             VEHICULAR HIJACKING
# 84   0110            HOMICIDE             FIRST DEGREE MURDER
# 849  031A             ROBBERY                 ARMED - HANDGUN
# 851  1140  DECEPTIVE PRACTICE                    EMBEZZLEMENT
#
#              Location Description  Arrest  Domestic  ...  Ward  \
# 6                       RESIDENCE   False     False  ...  10.0
# 20                      RESIDENCE    True     False  ...   6.0
# 84                       CAR WASH    True     False  ...  24.0
# 849                      SIDEWALK   False     False  ...  24.0
# 851  COMMERCIAL / BUSINESS OFFICE    True     False  ...  16.0
#
#      Community Area  FBI Code  X Coordinate Y Coordinate  Year  \
# 6              54.0        17     1186051.0    1817781.0  2021
# 20             44.0        03     1179448.0    1851073.0  2021
# 84             25.0       01A     1144907.0    1896933.0  2021
# 849            29.0        03     1152955.0    1892266.0  2021
# 851            67.0        12     1166240.0    1865581.0  2021
#
#                  Updated On   Latitude  Longitude  \
# 6    01/19/2024 03:40:50 PM  41.655116 -87.594883
# 20   09/14/2023 03:41:59 PM  41.746626 -87.618032
# 84   09/14/2023 03:41:59 PM  41.873191 -87.743447
# 849  04/18/2024 03:40:20 PM  41.860229 -87.714022
# 851  04/18/2024 03:40:20 PM  41.786729 -87.666017
#
#                           Location
# 6     (41.65511579, -87.594883198)
# 20   (41.746626309, -87.618031954)
# 84   (41.873191445, -87.743446563)
# 849   (41.860229103, -87.71402184)
# 851  (41.786729308, -87.666016839)
#
# [5 rows x 22 columns]

# %%
violentCrimeCodes = ['17', '03', '01A', '02', '04A', '01B']
dfCrime = dfCrime[dfCrime['FBI Code'].isin(violentCrimeCodes)]
print(dfCrime.shape)
dfCrime.head()
# Out:
# (18909, 22)
#             ID Case Number                    Date                  Block  \
# 6     12419690    JE295655  07/07/2021 10:30:00 AM  132XX S GREENWOOD AVE
# 20    12342615    JE202211  04/17/2021 03:20:00 PM    081XX S PRAIRIE AVE
# 84       26262    JE366265  09/08/2021 04:45:00 PM    047XX W HARRISON ST
# 849   12298539    JE148775  02/22/2021 01:36:00 PM      015XX S DRAKE AVE
# 3323  12485195    JE375807  09/01/2021 09:00:00 AM     022XX S KEDZIE AVE
#
#       IUCR Primary Type                     Description  \
# 6     1544  SEX OFFENSE  SEXUAL EXPLOITATION OF A CHILD
# 20    0325      ROBBERY             VEHICULAR HIJACKING
# 84    0110     HOMICIDE             FIRST DEGREE MURDER
# 849   031A      ROBBERY                 ARMED - HANDGUN
# 3323  1563  SEX OFFENSE           CRIMINAL SEXUAL ABUSE
#
#           Location Description  Arrest  Domestic  ...  Ward  Community Area  \
# 6                    RESIDENCE   False     False  ...  10.0            54.0
# 20                   RESIDENCE    True     False  ...   6.0            44.0
# 84                    CAR WASH    True     False  ...  24.0            25.0
# 849                   SIDEWALK   False     False  ...  24.0            29.0
# 3323  SCHOOL - PUBLIC BUILDING   False     False  ...  24.0            30.0
#
#       FBI Code  X Coordinate Y Coordinate  Year              Updated On  \
# 6           17     1186051.0    1817781.0  2021  01/19/2024 03:40:50 PM
# 20          03     1179448.0    1851073.0  2021  09/14/2023 03:41:59 PM
# 84         01A     1144907.0    1896933.0  2021  09/14/2023 03:41:59 PM
# 849         03     1152955.0    1892266.0  2021  04/18/2024 03:40:20 PM
# 3323        17     1155375.0    1888926.0  2021  12/23/2024 03:41:07 PM
#
#        Latitude  Longitude                       Location
# 6     41.655116 -87.594883   (41.65511579, -87.594883198)
# 20    41.746626 -87.618032  (41.746626309, -87.618031954)
# 84    41.873191 -87.743447  (41.873191445, -87.743446563)
# 849   41.860229 -87.714022   (41.860229103, -87.71402184)
# 3323  41.851016 -87.705228  (41.851015522, -87.705228282)
#
# [5 rows x 22 columns]

# %%
dfCrime = dfCrime[['FBI Code', 'Latitude', 'Longitude']]

# make our lon and lat into a point type for spacial join
dfCrime['geometry'] = dfCrime.apply(lambda row: Point(row['Longitude'], row['Latitude']), axis=1)
dfCrime = dfCrime[['FBI Code', 'geometry']]
dfCrime.head()
# Out:
#      FBI Code                                 geometry
# 6          17   POINT (-87.59488319800001 41.65511579)
# 20         03       POINT (-87.618031954 41.746626309)
# 84        01A  POINT (-87.74344656300001 41.873191445)
# 849        03        POINT (-87.71402184 41.860229103)
# 3323       17  POINT (-87.70522828199999 41.851015522)

# %%
# Read shapefile (automatically loads .shp, .shx, .dbf)
gdf = gpd.read_file("cb_2022_us_bg_500k/cb_2022_us_bg_500k.shp")

# View the first 5 rows
print(gdf.shape)
gdf.head()
# Out:
# (242297, 12)
#   STATEFP COUNTYFP TRACTCE BLKGRPCE               AFFGEOID         GEOID NAME  \
# 0      04      019  940800        2  1500000US040199408002  040199408002    2
# 1      04      003  000901        4  1500000US040030009014  040030009014    4
# 2      06      073  018102        3  1500000US060730181023  060730181023    3
# 3      06      073  007200        3  1500000US060730072003  060730072003    3
# 4      06      073  017702        3  1500000US060730177023  060730177023    3
#
#         NAMELSAD LSAD       ALAND  AWATER  \
# 0  Block Group 2   BG  2033911373   68536
# 1  Block Group 4   BG      486316       0
# 2  Block Group 3   BG      324091    3579
# 3  Block Group 3   BG      720442  709604
# 4  Block Group 3   BG      317237       0
#
#                                             geometry
# 0  POLYGON ((-112.41 31.857, -112.38 31.859, -112...
# 1  POLYGON ((-109.55 31.334, -109.55 31.339, -109...
# 2  POLYGON ((-117.37 33.182, -117.37 33.182, -117...
# 3  POLYGON ((-117.26 32.725, -117.26 32.726, -117...
# 4  POLYGON ((-117.3 33.052, -117.3 33.053, -117.3...

# %%
# make sure points match the crs of gdf
gdfPoints = gpd.GeoDataFrame(
    dfCrime, 
    geometry='geometry',
    crs="EPSG:4269"  # WGS84 coordinate reference system
)
gdfPoints.head()
# Out:
#      FBI Code                geometry
# 6          17  POINT (-87.595 41.655)
# 20         03  POINT (-87.618 41.747)
# 84        01A  POINT (-87.743 41.873)
# 849        03   POINT (-87.714 41.86)
# 3323       17  POINT (-87.705 41.851)

# %%
# Basic spatial join (points within polygons)
result = gpd.sjoin(
    gdfPoints, 
    gdf,
    how="left",       # 'left', 'right', or 'inner'
    predicate="within" # Spatial relationship
)
print(result.shape)
result.head()
# Out:
# (18909, 14)
#      FBI Code                geometry  index_right STATEFP COUNTYFP TRACTCE  \
# 6          17  POINT (-87.595 41.655)     160460.0      17      031  540101
# 20         03  POINT (-87.618 41.747)      61382.0      17      031  440300
# 84        01A  POINT (-87.743 41.873)     194628.0      17      031  252202
# 849        03   POINT (-87.714 41.86)     189000.0      17      031  291200
# 3323       17  POINT (-87.705 41.851)      30779.0      17      031  300900
#
#      BLKGRPCE               AFFGEOID         GEOID NAME       NAMELSAD LSAD  \
# 6           1  1500000US170315401011  170315401011    1  Block Group 1   BG
# 20          2  1500000US170314403002  170314403002    2  Block Group 2   BG
# 84          3  1500000US170312522023  170312522023    3  Block Group 3   BG
# 849         2  1500000US170312912002  170312912002    2  Block Group 2   BG
# 3323        2  1500000US170313009002  170313009002    2  Block Group 2   BG
#
#           ALAND    AWATER
# 6     2831943.0  508399.0
# 20     433247.0       0.0
# 84     190165.0       0.0
# 849    164526.0       0.0
# 3323   164099.0       0.0

# %%
crime = result['AFFGEOID'].value_counts()
crime
# Out:
# AFFGEOID
# 1500000US170318391001    132
# 1500000US170318424001     71
# 1500000US170310814011     67
# 1500000US170312605001     65
# 1500000US170318314001     61
#                         ...
# 1500000US170311006002      1
# 1500000US170318227012      1
# 1500000US170315610003      1
# 1500000US170310309001      1
# 1500000US170318399005      1
# Name: count, Length: 2064, dtype: int64

# %%
# export as a csv
crime.to_csv('Chicago_Violent_Crime_BG.csv')
